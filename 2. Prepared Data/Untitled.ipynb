# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('movies-1990on.csv')

# %%
dataset
# Out:
#       year       imdb                     title             test clean_test  \
# 0     2013  tt1711425             21 &amp; Over           notalk     notalk
# 1     2012  tt1343727                  Dredd 3D      ok-disagree         ok
# 2     2013  tt2024544          12 Years a Slave  notalk-disagree     notalk
# 3     2013  tt1272878                    2 Guns           notalk     notalk
# 4     2013  tt0453562                        42              men        men
# ...    ...        ...                       ...              ...        ...
# 1595  1990  tt0100403                Predator 2              men        men
# 1596  1990  tt0100405              Pretty Woman               ok         ok
# 1597  1990  tt0099810  The Hunt for Red October           notalk     notalk
# 1598  1990  tt0100802              Total Recall           notalk     notalk
# 1599  1990  tt0100814                   Tremors               ok         ok
#
# ...

# %%
for i in range (0, len(dataset)):
    if (dataset.iloc[i,4].find('dubious')!=-1):
        dataset.iloc[i,5] = 'PASS'
        print(dataset.iloc[i,5])
# Out:
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS
# PASS

# %%
dataset.to_csv('movies-1990on_dub.csv')
